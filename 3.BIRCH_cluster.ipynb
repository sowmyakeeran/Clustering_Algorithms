# %% [markdown]
#                                    3.BIRCH clustering Algorithm
#                            BALANCED ITERATIVE REDUCING CLUSTERING HIRERCHY

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Mall_Customers.csv')

# %%
dataset.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
x = dataset.iloc[:, [3, 4]].values

# %%
#BIRCH CLUSTER
from sklearn.cluster import Birch
birch = Birch(n_clusters = None)
label=birch.fit_predict(x)

# %%
supervised=pd.DataFrame(dataset)

# %%
supervised['Cluster_group']=label

# %%
supervised.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
#
#    Cluster_group
# 0             38
# 1              0
# 2             39
# 3              1
# 4             40

# %%
#printing the final dataset
import seaborn as sns
facet = sns.lmplot(data=dataset, x=dataset.columns[3], y=dataset.columns[4], hue=dataset.columns[5], 
                   fit_reg=False, legend=True, legend_out=True)
# Out:
# C:\Users\Yaazh\anaconda3\envs\ai\lib\site-packages\seaborn\regression.py:592: UserWarning: legend_out is deprecated from the `lmplot` function signature. Please update your code to pass it using `facet_kws`.
#   warnings.warn(msg, UserWarning)

# %%
#evalution metrics for clustering#silhoutte_score
from sklearn.metrics import silhouette_score
silhouette_score(x,label)
# Out:
# 0.12425932532230355
